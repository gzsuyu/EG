# %%
#let's get start!

# %%
import pandas as pd
import numpy as np

class format_convert(object):
    def __init__(self, file):
        self.file = file
        self.read_file()
        
    def read_file(self):
        self.df = pd.read_csv(self.file,index_col=0)
        
    def ymd(self):
        from datetime import datetime
        EGDTC = self.df[["Day of ECG","Month of ECG","Year of ECG"]].apply(lambda x: '-'.join(x.map(str)), axis=1).apply(lambda x: datetime.strptime(x, "%d-%M-%Y"))
        EGDTC = EGDTC.apply(lambda x: datetime.strftime(x, "%d-%b-%Y").upper())
        return EGDTC
    
    def column_convert(self,column_name):
        column_name = column_name
        result = pd.DataFrame(columns=["STUDYID","DOMAIN","USUBJID","EGEVAL","EGDY","EGDTC","VISITNUM", "VISIT","VISITDY", "EGPOS","EGMETHOD","EGTEST","EGTESTCD" ,"EGORRES","EGORRESU","EGSTRRESC","EGSTRESN","EGSTRESU","EGCAT","EGSTAT"])
        
        #general value copy
        result[["STUDYID","EGEVAL","EGDY"]]= self.df[["Clinical Trial Number","Evaluation Method","Rel day of ECG to Start of Trt"]]
        result["VISITNUM"] =result["VISIT"] = result["VISITDY"] = self.df["Visit"]
        
        #special copy
        result["EGORRES"] = result["EGSTRRESC"] = result["EGSTRESN"] = self.df[column_name]
        result["EGSTAT"] = np.where(self.df[column_name]==".","Not done",self.df[column_name])
        result["USUBJID"] = self.df[["Subject Number","Clinical Trial Number"]].apply(lambda x:'||'.join(x.map(str)),axis=1)
        result['EGDTC'] = self.ymd()

        #hardcode 
        hardcode_dict = {
            "Ventricular Rate":{"EGTEST":"VRMEAN","EGTESTCD":"Summary (Mean) Ventricular Rate"},
            "PR Interval":{"EGTEST":"PRMEAN","EGTESTCD":"Summary (Mean) PR Duration"},
            "QRS Interval":{"EGTEST":"QRSDUR","EGTESTCD":"Summary (Mean) QRS Duration"},
            "QT Interval":{"EGTEST":"QTMEAN","EGTESTCD":"Summary (Mean) QT Duration"},
            "Sinus Rhythm":{"EGTEST":"RHYRATE","EGTESTCD":"Rhythm and rate"},
            "QTc Interval Calc Bazett":{"EGTEST":"QTCBMEAN","EGTESTCD":"QTcB - Bazetts Correction Formula (Mean)"},
            "QTc Interval Calc Fridericia":{"EGTEST":"QTCFMEAN","EGTESTCD":"QTcF-Fridericias Correction Formul(Mean)"}
        }#modify dictionary when need to change
        result["EGTEST"]= hardcode_dict[column_name]["EGTEST"]
        result["EGTESTCD"]= hardcode_dict[column_name]["EGTESTCD"]
        result["DOMAIN"] = "EG"
        result["EGPOS"] = "SUPINE"
        result["EGMETHOD"] = "12 LEAD STANDARD"
        result["EGORRESU"] = result["EGORRES"]
        result["EGSTRESU"] = result["EGTEST"]
        result["EGCAT"]= "Measurement"
        return result
        
    def generate_result(self):
        #modify when need to change
        column_list= ["Ventricular Rate","PR Interval","QRS Interval","QT Interval","Sinus Rhythm","QTc Interval Calc Bazett","QTc Interval Calc Fridericia"]
        
        frames = []
        for column_name in self.df.columns:
            if column_name in column_list:
                column_name_df = self.column_convert(column_name)
                frames.append(column_name_df)
            
        result_df = pd.concat(frames)
        result_df = result_df.reset_index(drop=True)
        return result_df

# %%
#the reason of not combining the file then run the method one time is for convenience of adding other file like "ecg4" in the future
def create_egstandard(directory):
    f = []
    for i in range(1,4):
        name = "ecg{0}".format(i)
        d = directory+"/{0}.csv".format(name)
        res = format_convert(file=d).generate_result()
        f.append(res)

    eg_standard = pd.concat(f).reset_index(drop=True)
    eg_standard["EGSEQ"] = eg_standard.groupby(["USUBJID"]).cumcount() + 1
    eg_standard.to_csv(directory+"/EG Standard.csv")
    return eg_standard

# %%
eg_standard = create_egstandard('C:/Users/gzsuy/Desktop/To Candidates[13236]/raw') #result can also be found in local drive

# %%
eg_standard
# Out:
#       STUDYID DOMAIN           USUBJID        EGEVAL EGDY        EGDTC  \
# 0       30121     EG  571331322||30121  INVESTIGATOR   -6  26-JAN-2011
# 1       30121     EG  571331323||30121  INVESTIGATOR  -23  02-JAN-2011
# 2       30121     EG  571331324||30121  INVESTIGATOR    1  01-JAN-2011
# 3       30121     EG  411331322||30121  INVESTIGATOR  -14  09-JAN-2010
# 4       30121     EG  411331323||30121  INVESTIGATOR  -21  23-JAN-2010
# 5       30121     EG  411331325||30121  INVESTIGATOR  -21  20-JAN-2011
# 6       30121     EG  411331326||30121  INVESTIGATOR   -3  09-JAN-2011
# 7       30121     EG  541341322||30121  INVESTIGATOR    .  19-JAN-2011
# 8       30121     EG  541341323||30121  INVESTIGATOR  -11  20-JAN-2011
# 9       30121     EG  541341324||30121  INVESTIGATOR   -3  28-JAN-2011
# 10      30121     EG  541341325||30121  INVESTIGATOR  -14  26-JAN-2011
# 11      30121     EG  541341326||30121  INVESTIGATOR  -14  27-JAN-2011
# 12      30121     EG  541341327||30121  INVESTIGATOR    .  27-JAN-2011
# 13      30121     EG  541341328||30121  INVESTIGATOR    .  31-JAN-2011
# 14      30121     EG  541341330||30121  INVESTIGATOR    .  09-JAN-2011
# 15      30121     EG  541341331||30121  INVESTIGATOR  -18  10-JAN-2011
# 16      30121     EG  541341332||30121  INVESTIGATOR  -18  10-JAN-2011
# 17      30121     EG  541341333||30121  INVESTIGATOR   -8  13-JAN-2011
# 18      30121     EG  671331322||30121  INVESTIGATOR  -14  10-JAN-2011
# 19      30121     EG  671331323||30121  INVESTIGATOR   -9  15-JAN-2011
# 20      30121     EG  671331324||30121  INVESTIGATOR  -15  31-JAN-2011
# 21      30121     EG  671341322||30121  INVESTIGATOR   -6  09-JAN-2010
# 22      30121     EG  671341323||30121  INVESTIGATOR   -7  15-JAN-2010
# 23      30121     EG  671341324||30121  INVESTIGATOR   -9  19-JAN-2011
# 24      30121     EG  671341325||30121  INVESTIGATOR   -5  18-JAN-2011
# 25      30121     EG  671341326||30121  INVESTIGATOR    .  20-JAN-2011
# 26      30121     EG  671341327||30121  INVESTIGATOR   -5  24-JAN-2011
# 27      30121     EG  671351322||30121  INVESTIGATOR  -13  19-JAN-2010
# 28      30121     EG  671351323||30121  INVESTIGATOR  -13  19-JAN-2010
# 29      30121     EG  671351324||30121  INVESTIGATOR    .  10-JAN-2011
# ...       ...    ...               ...           ...  ...          ...
# 3274    30121     EG  271391326||30121  INVESTIGATOR  -13  26-JAN-2011
# 3275    30121     EG  271391327||30121  INVESTIGATOR   -7  09-JAN-2011
# 3276    30121     EG  271401322||30121  INVESTIGATOR   -6  19-JAN-2010
# 3277    30121     EG  271401322||30121  INVESTIGATOR  121  23-JAN-2010
# 3278    30121     EG  271401322||30121  INVESTIGATOR  436  03-JAN-2011
# 3279    30121     EG  271401323||30121  INVESTIGATOR   -3  09-JAN-2010
# 9              Summary (Mean) Ventricular Rate       83       83        83
# 10             Summary (Mean) Ventricular Rate       56       56        56
# 11             Summary (Mean) Ventricular Rate       75       75        75
# 12             Summary (Mean) Ventricular Rate       58       58        58
# 13             Summary (Mean) Ventricular Rate       52       52        52
# 14             Summary (Mean) Ventricular Rate       73       73        73
# 15             Summary (Mean) Ventricular Rate       84       84        84
# 16             Summary (Mean) Ventricular Rate       95       95        95
# 17             Summary (Mean) Ventricular Rate       79       79        79
# 18             Summary (Mean) Ventricular Rate       89       89        89
# 19             Summary (Mean) Ventricular Rate       88       88        88
# 20             Summary (Mean) Ventricular Rate       68       68        68
# 21             Summary (Mean) Ventricular Rate       68       68        68
# 22             Summary (Mean) Ventricular Rate       92       92        92
# 23             Summary (Mean) Ventricular Rate       78       78        78
# 24             Summary (Mean) Ventricular Rate       77       77        77
# 25             Summary (Mean) Ventricular Rate      118      118       118
# 26             Summary (Mean) Ventricular Rate       72       72        72
# 27             Summary (Mean) Ventricular Rate       60       60        60
# 28             Summary (Mean) Ventricular Rate       73       73        73
# 29             Summary (Mean) Ventricular Rate       66       66        66
# ...                                        ...      ...      ...       ...
# 3274  QTcF-Fridericias Correction Formul(Mean)  408.602  408.602   408.602
# 3275  QTcF-Fridericias Correction Formul(Mean)  416.528  416.528   416.528
# 3276  QTcF-Fridericias Correction Formul(Mean)  437.121  437.121   437.121
# 3277  QTcF-Fridericias Correction Formul(Mean)  428.163  428.163   428.163
# 3278  QTcF-Fridericias Correction Formul(Mean)  430.042  430.042   430.042
# 3279  QTcF-Fridericias Correction Formul(Mean)   404.25   404.25    404.25
# 3280  QTcF-Fridericias Correction Formul(Mean)  437.934  437.934   437.934
# 3281  QTcF-Fridericias Correction Formul(Mean)  407.809  407.809   407.809
# 3282  QTcF-Fridericias Correction Formul(Mean)   440.42   440.42    440.42
# 3283  QTcF-Fridericias Correction Formul(Mean)  412.097  412.097   412.097
# 3284  QTcF-Fridericias Correction Formul(Mean)  449.924  449.924   449.924
# 3285  QTcF-Fridericias Correction Formul(Mean)  409.343  409.343   409.343
# 3286  QTcF-Fridericias Correction Formul(Mean)  413.009  413.009   413.009
# 3287  QTcF-Fridericias Correction Formul(Mean)      446      446       446
# 3288  QTcF-Fridericias Correction Formul(Mean)  402.374  402.374   402.374
# 3289  QTcF-Fridericias Correction Formul(Mean)  425.348  425.348   425.348
# 3290  QTcF-Fridericias Correction Formul(Mean)  423.962  423.962   423.962
# 3291  QTcF-Fridericias Correction Formul(Mean)  426.065  426.065   426.065
# 3292  QTcF-Fridericias Correction Formul(Mean)  407.238  407.238   407.238
# 3293  QTcF-Fridericias Correction Formul(Mean)  416.528  416.528   416.528
# 3294  QTcF-Fridericias Correction Formul(Mean)      418      418       418
# 3295  QTcF-Fridericias Correction Formul(Mean)  438.415  438.415   438.415
# 3296  QTcF-Fridericias Correction Formul(Mean)  373.959  373.959   373.959
# 3297  QTcF-Fridericias Correction Formul(Mean)  420.617  420.617   420.617
# 3298  QTcF-Fridericias Correction Formul(Mean)   467.57   467.57    467.57
# 3299  QTcF-Fridericias Correction Formul(Mean)  441.116  441.116   441.116
# 3300  QTcF-Fridericias Correction Formul(Mean)  387.093  387.093   387.093
# 3301  QTcF-Fridericias Correction Formul(Mean)  459.573  459.573   459.573
